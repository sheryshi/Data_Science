# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('placement (1).csv')

# %%
plt.scatter(df['cgpa'],df['placed'])
plt.xlabel('CGpa')
plt.ylabel('packaGE')
# Out:
# Text(0, 0.5, 'packaGE')

# %%
df.columns
# Out:
# Index(['cgpa', 'placement_exam_marks', 'placed'], dtype='object')

# %%
x=df.iloc[:,0:1]

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\shery\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x_test
# Out:
#      cgpa
# 37   8.51
# 726  7.93
# 846  6.99
# 295  6.02
# 924  6.85
# ..    ...
# 839  6.44
# 810  7.14
# 930  6.94
# 616  7.09
# 809  6.39
#
# [200 rows x 1 columns]

# %%
y_pred
# Out:
# array([0.49947742])

# %%
y_test
# Out:
# 37     1
# 726    0
# 846    0
# 295    0
# 924    1
#       ..
# 839    1
# 810    1
# 930    1
# 616    1
# 809    1
# Name: placed, Length: 200, dtype: int64

# %%
df.columns
# Out:
# Index(['cgpa', 'placement_exam_marks', 'placed'], dtype='object')
